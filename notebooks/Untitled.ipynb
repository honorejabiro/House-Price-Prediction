# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("../data/housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
x = data.drop(['median_house_value'], axis=1)
y = data["median_house_value"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
train_data = x_test.join(y_test)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15998    -122.47     37.75                46.0       3238.0           544.0
# 13106    -121.37     38.41                14.0       3727.0           685.0
# 3868     -118.45     34.16                33.0       2544.0           500.0
# 13094    -121.36     38.56                20.0       1232.0           332.0
# 15333    -117.33     33.22                21.0       2868.0           602.0
# ...          ...       ...                 ...          ...             ...
# 6361     -117.97     34.13                33.0       2038.0           473.0
# 11099    -117.88     33.82                17.0       2247.0           705.0
# 13163    -121.38     36.85                13.0       4115.0           782.0
# 8010     -118.12     33.86                34.0       2116.0           427.0
# 16157    -122.49     37.77                52.0       2342.0           458.0
#
#        population  households  median_income ocean_proximity  \
# 15998      1293.0       470.0         6.1592        NEAR BAY
# 13106      1741.0       646.0         3.5625          INLAND
# 3868       1035.0       492.0         4.4750       <1H OCEAN
# 13094       667.0       288.0         1.8288          INLAND
# 15333       855.0       559.0         2.7846      NEAR OCEAN
# ...           ...         ...            ...             ...
# 6361       1546.0       469.0         3.4777          INLAND
# 11099      1382.0       618.0         3.8631       <1H OCEAN
# 13163      2903.0       747.0         3.7316          INLAND
# 8010        972.0       396.0         4.8516       <1H OCEAN
# 16157      1170.0       458.0         3.7036        NEAR BAY
#
#        median_house_value
# 15998            381700.0
# 13106            125700.0
# 3868             314800.0
# 13094             32500.0
# 15333             91200.0
# ...                   ...
# 6361             144500.0
# 11099            225000.0
# 13163            192400.0
# 8010             213600.0
# 16157            369200.0
#
# [4087 rows x 10 columns]

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15998    -122.47     37.75                46.0       3238.0           544.0
# 13106    -121.37     38.41                14.0       3727.0           685.0
# 3868     -118.45     34.16                33.0       2544.0           500.0
# 13094    -121.36     38.56                20.0       1232.0           332.0
# 15333    -117.33     33.22                21.0       2868.0           602.0
# ...          ...       ...                 ...          ...             ...
# 6361     -117.97     34.13                33.0       2038.0           473.0
# 11099    -117.88     33.82                17.0       2247.0           705.0
# 13163    -121.38     36.85                13.0       4115.0           782.0
# 8010     -118.12     33.86                34.0       2116.0           427.0
# 16157    -122.49     37.77                52.0       2342.0           458.0
#
#        population  households  median_income ocean_proximity  \
# 15998      1293.0       470.0         6.1592        NEAR BAY
# 13106      1741.0       646.0         3.5625          INLAND
# 3868       1035.0       492.0         4.4750       <1H OCEAN
# 13094       667.0       288.0         1.8288          INLAND
# 15333       855.0       559.0         2.7846      NEAR OCEAN
# ...           ...         ...            ...             ...
# 6361       1546.0       469.0         3.4777          INLAND
# 11099      1382.0       618.0         3.8631       <1H OCEAN
# 13163      2903.0       747.0         3.7316          INLAND
# 8010        972.0       396.0         4.8516       <1H OCEAN
# 16157      1170.0       458.0         3.7036        NEAR BAY
#
#        median_house_value
# 15998            381700.0
# 13106            125700.0
# 3868             314800.0
# 13094             32500.0
# 15333             91200.0
# ...                   ...
# 6361             144500.0
# 11099            225000.0
# 13163            192400.0
# 8010             213600.0
# 16157            369200.0
#
# [4087 rows x 10 columns]

# %%
train_data.drop("ocean_proximity", axis=1).corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924478           -0.135120     0.049062
# latitude            -0.924478  1.000000            0.047570    -0.041229
# housing_median_age  -0.135120  0.047570            1.000000    -0.372267
# total_rooms          0.049062 -0.041229           -0.372267     1.000000
# total_bedrooms       0.074538 -0.070569           -0.336415     0.928747
# population           0.105444 -0.113546           -0.291225     0.834254
# households           0.064065 -0.079900           -0.320756     0.921874
# median_income       -0.005946 -0.092492           -0.124613     0.218148
# median_house_value  -0.047352 -0.143374            0.096292     0.141921
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.074538    0.105444    0.064065      -0.005946
# latitude                 -0.070569   -0.113546   -0.079900      -0.092492
# housing_median_age       -0.336415   -0.291225   -0.320756      -0.124613
# total_rooms               0.928747    0.834254    0.921874       0.218148
# total_bedrooms            1.000000    0.857536    0.982184       0.002074
# population                0.857536    1.000000    0.885057       0.014344
# households                0.982184    0.885057    1.000000       0.028988
# median_income             0.002074    0.014344    0.028988       1.000000
# median_house_value        0.046856   -0.024715    0.066611       0.704561
#
#                     median_house_value
# longitude                    -0.047352
# latitude                     -0.143374
# housing_median_age            0.096292
# total_rooms                   0.141921
# total_bedrooms                0.046856
# population                   -0.024715
# households                    0.066611
# median_income                 0.704561
# median_house_value            1.000000

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(
    train_data.drop("ocean_proximity", axis=1).corr(),
    annot=True,
    cmap="YlGnBu"
)
plt.title("Correlation Matrix")
plt.show()

# %%
train_data["total_rooms"] = np.log(train_data['total_rooms'] + 1)
train_data["total_bedrooms"] = np.log(train_data['total_bedrooms'] + 1)
train_data["population"] = np.log(train_data['population'] + 1)
train_data["households"] = np.log(train_data['households'] + 1)

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     1774
# INLAND        1282
# NEAR OCEAN     540
# NEAR BAY       491
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data['ocean_proximity']).astype(int)
# Out:
#        <1H OCEAN  INLAND  NEAR BAY  NEAR OCEAN
# 15998          0       0         1           0
# 13106          0       1         0           0
# 3868           1       0         0           0
# 13094          0       1         0           0
# 15333          0       0         0           1
# ...          ...     ...       ...         ...
# 6361           0       1         0           0
# 11099          1       0         0           0
# 13163          0       1         0           0
# 8010           1       0         0           0
# 16157          0       0         1           0
#
# [4087 rows x 4 columns]
